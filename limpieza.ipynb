# %% [markdown]
# # EDA de los alojamientos turísticos en Madrid (Airbnb)
#
# En este notebook realizamos un **Análisis Exploratorio de Datos (EDA)** sobre los alojamientos turísticos de Madrid anunciados en Airbnb, utilizando el dataset `listings.csv` de Inside Airbnb.
#
# **Objetivo del análisis**
#
# - Entender cómo se distribuyen los precios por noche.
# - Analizar el impacto de:
#   - la **ubicación** (distritos / barrios),
#   - el **tipo de alojamiento**,
#   - la **capacidad (número de huéspedes)**
#
# en el **precio por noche**.
#
# Este notebook corresponde al archivo `main.ipynb` del proyecto `EDA_Alojamientos_turisticos_Madrid`.

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo de gráficos
plt.style.use("ggplot")
sns.set(rc={"figure.figsize": (10, 5)})

# Crear carpeta de imágenes si no existe
os.makedirs("src/img", exist_ok=True)

# %%
# Ruta al fichero de datos
ruta_datos = "src/data/listings.csv"

# Carga del dataset
df = pd.read_csv(ruta_datos, low_memory=False)

# Vistazo rápido
df.head()
# Out:
#       id                                          name   host_id  \
# 0  21853                          Bright and airy room   83531.0
# 1  30320                         Apartamentos Dana Sol  130907.0
# 2  30959               Beautiful loft in Madrid Center  132883.0
# 3  40916                   Apartasol Apartamentos Dana  130907.0
# 4  62423  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID  303845.0
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0            Abdel              Latina      Cármenes  40.40381   -3.74130
# 1  Danuta Weronika              Centro           Sol  40.41476   -3.70418
# 2           Angela              Centro   Embajadores  40.41259   -3.70105
# 3  Danuta Weronika              Centro   Universidad  40.42247   -3.70577
# 4           Arturo              Centro      Justicia  40.41884   -3.69655
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    NaN             4.0               33.0  2018-07-15
# 1  Entire home/apt  157.0             5.0              173.0  2025-08-27
# 2  Entire home/apt    NaN             3.0                8.0  2017-05-30
# 3  Entire home/apt  143.0             5.0               53.0  2025-09-11
# 4     Private room   65.0             1.0              249.0  2025-09-05
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.25                             2.0             198.0
# 1               0.93                            17.0             342.0
# 2               0.06                             1.0               0.0
# 3               0.29                            17.0             341.0
# 4               2.78                             3.0             299.0
#
#    number_of_reviews_ltm license;
# 0                    0.0        ;
# 1                    1.0        ;
# 2                    0.0        ;
# 3                    4.0        ;
# 4                   41.0        ;

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25094 entries, 0 to 25093
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              25094 non-null  object
#  1   name                            22442 non-null  object
#  2   host_id                         22442 non-null  float64
#  3   host_name                       22349 non-null  object
#  4   neighbourhood_group             22442 non-null  object
#  5   neighbourhood                   22442 non-null  object
#  6   latitude                        22442 non-null  float64
#  7   longitude                       22442 non-null  float64
#  8   room_type                       22442 non-null  object
#  9   price                           16931 non-null  float64
#  10  minimum_nights                  22442 non-null  float64
#  11  number_of_reviews               22442 non-null  float64
#  12  last_review                     17670 non-null  object
#  13  reviews_per_month               17670 non-null  float64
#  14  calculated_host_listings_count  22442 non-null  float64
#  15  availability_365                22442 non-null  float64
#  16  number_of_reviews_ltm           22442 non-null  float64
#  17  license;                        22435 non-null  object
# dtypes: float64(10), object(8)
# memory usage: 3.4+ MB

# %%
df = df[df.isna().sum(axis=1) <= 10]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22442 entries, 0 to 25093
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22442 non-null  object
#  1   name                            22442 non-null  object
#  2   host_id                         22442 non-null  float64
#  3   host_name                       22349 non-null  object
#  4   neighbourhood_group             22442 non-null  object
#  5   neighbourhood                   22442 non-null  object
#  6   latitude                        22442 non-null  float64
#  7   longitude                       22442 non-null  float64
#  8   room_type                       22442 non-null  object
#  9   price                           16931 non-null  float64
#  10  minimum_nights                  22442 non-null  float64
#  11  number_of_reviews               22442 non-null  float64
#  12  last_review                     17670 non-null  object
#  13  reviews_per_month               17670 non-null  float64
#  14  calculated_host_listings_count  22442 non-null  float64
#  15  availability_365                22442 non-null  float64
#  16  number_of_reviews_ltm           22442 non-null  float64
#  17  license;                        22435 non-null  object
# dtypes: float64(10), object(8)
# memory usage: 3.3+ MB

# %%
df[df["host_name"].isna()]
# Out:
#                         id                                             name  \
# 743                6899113                       Habitación en Vallehermoso
# 854                7712666               LINDO APARTAMENTO MUY BIEN SITUADO
# 978                8963605                             loft cerca de atocha
# 3210              22943516  A3 Comfortable And Pleasant Apartment In Madrid
# 3211              22943847  A5 Comfortable And Pleasant Apartment In Madrid
# ...                    ...                                              ...
# 24436  1471538723582381999                         Apartamento en Noviciado
# 24437  1471610422615046582                       Apartamento en Noviciado 2
# 24807  1496936866768919379                    Aparta-Estudio en Plaza Mayor
# 25062  1506426210772187082                    Studio in Plaza Callao Madrid
# 25064  1506443026582693054                    A Fascinate Studio In Madrid.
#
#            host_id host_name neighbourhood_group neighbourhood   latitude  \
# 743     36068881.0       NaN            Chamberí  Vallehermoso  40.438820
# 854     40516896.0       NaN              Tetuán   Castillejos  40.462600
# 978     46845753.0       NaN  Puente de Vallecas     San Diego  40.395250
# 3210    91506664.0       NaN              Centro   Embajadores  40.405418
# 3211    91506664.0       NaN              Centro   Embajadores  40.405708
# ...            ...       ...                 ...           ...        ...
# 24436  518331793.0       NaN              Centro   Universidad  40.425558
# 24437  518331793.0       NaN              Centro   Universidad  40.425558
# 24807   91506664.0       NaN              Centro           Sol  40.414688
# 25062   91506664.0       NaN              Centro   Universidad  40.421598
# 25064   91506664.0       NaN              Centro   Universidad  40.421250
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 743    -3.706190     Private room    NaN             1.0                0.0
# 854    -3.690190  Entire home/apt    NaN             7.0                0.0
# 978    -3.668770  Entire home/apt    NaN             1.0                0.0
# 3210   -3.701753  Entire home/apt  100.0             2.0              174.0
# 3211   -3.701652  Entire home/apt   95.0             2.0              121.0
# ...          ...              ...    ...             ...                ...
# 24436  -3.705515  Entire home/apt  241.0             1.0                7.0
# 24437  -3.705515  Entire home/apt  327.0             1.0                7.0
# 24807  -3.707189  Entire home/apt  143.0             1.0                0.0
# 25062  -3.706432  Entire home/apt  123.0             2.0                0.0
# 25064  -3.703630  Entire home/apt  133.0             2.0                0.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 743           NaN                NaN                             1.0
# 854           NaN                NaN                             1.0
# 978           NaN                NaN                             1.0
# 3210   2025-08-25               1.88                            16.0
# 3211   2025-03-23               1.31                            16.0
# ...           ...                ...                             ...
# 24436  2025-08-31               6.18                            53.0
# 24437  2025-08-30               6.56                            53.0
# 24807         NaN                NaN                            16.0
# 25062         NaN                NaN                            16.0
# 25064         NaN                NaN                            16.0
#
#        availability_365  number_of_reviews_ltm  \
# 743                 0.0                    0.0
# 854                 0.0                    0.0
# 978                 0.0                    0.0
# 3210              329.0                   15.0
# 3211              317.0                    6.0
# ...                 ...                    ...
# 24436               0.0                    7.0
# 24437               0.0                    7.0
# 24807             323.0                    0.0
# 25062             314.0                    0.0
# 25064             299.0                    0.0
#
#                                                 license;
# 743                                                    ;
# 854                                                    ;
# 978                                                    ;
# 3210                                        H28391AAV68;
# 3211                                        H28391AAV68;
# ...                                                  ...
# 24436  ESFCTU00000304400021559900000000000000000VT-50...
# 24437  ESFCTU00000304400021559900000000000000000VT-50...
# 24807  ESHFNT0000280910004794110010000000000000000000...
# 25062  ESHFNT0000281080000856480020000000000000000000...
# 25064  ESHFNT0000281080001195410010000000000000000000...
#
# [93 rows x 18 columns]

# %%
df["host_name"] = df["host_name"].fillna("Desconocido")

# %%
df["host_name"].value_counts()
# Out:
# host_name
# Francisco Andres    462
# Home Club           416
# Ukio                381
# Jorge               339
# MIT House           334
#                    ...
# Roi                   1
# Gustavo Miguel        1
# Dunia Dalila          1
# Edelmira              1
# Tatiana Camila        1
# Name: count, Length: 3648, dtype: int64

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22442 entries, 0 to 25093
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22442 non-null  object
#  1   name                            22442 non-null  object
#  2   host_id                         22442 non-null  float64
#  3   host_name                       22442 non-null  object
#  4   neighbourhood_group             22442 non-null  object
#  5   neighbourhood                   22442 non-null  object
#  6   latitude                        22442 non-null  float64
#  7   longitude                       22442 non-null  float64
#  8   room_type                       22442 non-null  object
#  9   price                           16931 non-null  float64
#  10  minimum_nights                  22442 non-null  float64
#  11  number_of_reviews               22442 non-null  float64
#  12  last_review                     17670 non-null  object
#  13  reviews_per_month               17670 non-null  float64
#  14  calculated_host_listings_count  22442 non-null  float64
#  15  availability_365                22442 non-null  float64
#  16  number_of_reviews_ltm           22442 non-null  float64
#  17  license;                        22435 non-null  object
# dtypes: float64(10), object(8)
# memory usage: 3.3+ MB

# %%
df[df["license;"].isna()]
# Out:
#                         id                                               name  \
# 427                3712285                Hipster style & perfect location ;)
# 18175  1201433668441586580  Penthouse 3 B Boutique Duplex terraces; 3-4 pe...
# 18178  1201446110425479538    1 Apartament Atico 3º A (nº 6); up to 4-6 guest
# 18179  1201449248718083992   Boutique Apartment Entreplanta (nº 1); 3-5 guest
# 18180  1201452489545612646  Studio Apartment 1ºB (nº3) or 2ºB (nº5); 2-4 g...
# 21996  1380771706672353061                 Luxury Collection; Conde de Aranda
# 22218  1390793860643108945   San Blas Apartment; Pool and Padel for 4 Guests.
#
#            host_id            host_name    neighbourhood_group neighbourhood  \
# 427     18396400.0               Daniel                 Centro   Embajadores
# 18175  589559365.0               Daniel     Puente de Vallecas      Numancia
# 18178  589559365.0               Daniel     Puente de Vallecas      Numancia
# 18179  589559365.0               Daniel     Puente de Vallecas      Numancia
# 18180  589559365.0               Daniel     Puente de Vallecas      Numancia
# 21996    5697443.0  The Everywhere Home              Salamanca     Recoletos
# 22218  687823325.0              Natalia  San Blas - Canillejas      Simancas
#
#         latitude  longitude        room_type   price  minimum_nights  \
# 427    40.411000  -3.703280  Entire home/apt     NaN           300.0
# 18175  40.401340  -3.663700  Entire home/apt   147.0             1.0
# 18178  40.401830  -3.664570  Entire home/apt   139.0             2.0
# 18179  40.400810  -3.664490  Entire home/apt   145.0             1.0
# 18180  40.401340  -3.663700  Entire home/apt   130.0             1.0
# 21996  40.422244  -3.686983  Entire home/apt  1725.0             3.0
# 22218  40.439161  -3.617413  Entire home/apt    97.0             1.0
#
#        number_of_reviews last_review  reviews_per_month  \
# 427                 10.0  2018-06-10               0.08
# 18175                5.0  2025-09-05               0.45
# 18178                9.0  2025-08-21               1.37
# 18179                3.0  2025-05-12               0.27
# 18180               10.0  2025-07-06               0.91
# 21996                0.0         NaN                NaN
# 22218               25.0  2025-09-03               5.03
#
#        calculated_host_listings_count  availability_365  \
# 427                               1.0              83.0
# 18175                             5.0              73.0
# 18178                             5.0              62.0
# 18179                             5.0              72.0
# 18180                             5.0              80.0
# 21996                             7.0             107.0
# 22218                             1.0             351.0
#
#        number_of_reviews_ltm license;
# 427                      0.0      NaN
# 18175                    5.0      NaN
# 18178                    9.0      NaN
# 18179                    3.0      NaN
# 18180                   10.0      NaN
# 21996                    0.0      NaN
# 22218                   25.0      NaN

# %%
df["license;"].value_counts()
# Out:
# license;
# ;                                                         14266
# Exempt;                                                     603
# En proceso;                                                 276
# ESABCD123456789123456789123456789123456-HH-7891234567;       49
# 350202309690;                                                27
#                                                           ...
# ESFCTU00002811800046654500000000000000000000VT-143906;        1
# ESFCTU00000607000021559700000000000000000VT-509234-A1;        1
# ESFCNT00002810400043401100000000000000000000000000007;        1
# ESFCTU000028091000091767000000000000000000000VT130756;        1
# ESFCNT00002810900032334100000000000000000000000000005;        1
# Name: count, Length: 6101, dtype: int64

# %%
df["license;"]=df["license;"].fillna("desconocido")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22442 entries, 0 to 25093
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22442 non-null  object
#  1   name                            22442 non-null  object
#  2   host_id                         22442 non-null  float64
#  3   host_name                       22442 non-null  object
#  4   neighbourhood_group             22442 non-null  object
#  5   neighbourhood                   22442 non-null  object
#  6   latitude                        22442 non-null  float64
#  7   longitude                       22442 non-null  float64
#  8   room_type                       22442 non-null  object
#  9   price                           16931 non-null  float64
#  10  minimum_nights                  22442 non-null  float64
#  11  number_of_reviews               22442 non-null  float64
#  12  last_review                     17670 non-null  object
#  13  reviews_per_month               17670 non-null  float64
#  14  calculated_host_listings_count  22442 non-null  float64
#  15  availability_365                22442 non-null  float64
#  16  number_of_reviews_ltm           22442 non-null  float64
#  17  license;                        22442 non-null  object
# dtypes: float64(10), object(8)
# memory usage: 3.3+ MB

# %%
df_precios = df[df["price"].isna()==False]
df_precios=df_precios.drop(columns=["last_review","reviews_per_month"])
df_precios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16931 entries, 1 to 25093
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16931 non-null  object
#  1   name                            16931 non-null  object
#  2   host_id                         16931 non-null  float64
#  3   host_name                       16931 non-null  object
#  4   neighbourhood_group             16931 non-null  object
#  5   neighbourhood                   16931 non-null  object
#  6   latitude                        16931 non-null  float64
#  7   longitude                       16931 non-null  float64
#  8   room_type                       16931 non-null  object
#  9   price                           16931 non-null  float64
#  10  minimum_nights                  16931 non-null  float64
#  11  number_of_reviews               16931 non-null  float64
#  12  calculated_host_listings_count  16931 non-null  float64
#  13  availability_365                16931 non-null  float64
#  14  number_of_reviews_ltm           16931 non-null  float64
#  15  license;                        16931 non-null  object
# dtypes: float64(9), object(7)
# memory usage: 2.2+ MB

# %%
df_reviews = df[df["last_review"].isna()==False]
df_reviews=df_reviews.drop(columns=["price"])
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17670 entries, 0 to 24975
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17670 non-null  object
#  1   name                            17670 non-null  object
#  2   host_id                         17670 non-null  float64
#  3   host_name                       17670 non-null  object
#  4   neighbourhood_group             17670 non-null  object
#  5   neighbourhood                   17670 non-null  object
#  6   latitude                        17670 non-null  float64
#  7   longitude                       17670 non-null  float64
#  8   room_type                       17670 non-null  object
#  9   minimum_nights                  17670 non-null  float64
#  10  number_of_reviews               17670 non-null  float64
#  11  last_review                     17670 non-null  object
#  12  reviews_per_month               17670 non-null  float64
#  13  calculated_host_listings_count  17670 non-null  float64
#  14  availability_365                17670 non-null  float64
#  15  number_of_reviews_ltm           17670 non-null  float64
#  16  license;                        17670 non-null  object
# dtypes: float64(9), object(8)
# memory usage: 2.4+ MB

# %%
df_completo = df.drop(columns=["price","last_review","reviews_per_month"])
df_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22442 entries, 0 to 25093
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              22442 non-null  object
#  1   name                            22442 non-null  object
#  2   host_id                         22442 non-null  float64
#  3   host_name                       22442 non-null  object
#  4   neighbourhood_group             22442 non-null  object
#  5   neighbourhood                   22442 non-null  object
#  6   latitude                        22442 non-null  float64
#  7   longitude                       22442 non-null  float64
#  8   room_type                       22442 non-null  object
#  9   minimum_nights                  22442 non-null  float64
#  10  number_of_reviews               22442 non-null  float64
#  11  calculated_host_listings_count  22442 non-null  float64
#  12  availability_365                22442 non-null  float64
#  13  number_of_reviews_ltm           22442 non-null  float64
#  14  license;                        22442 non-null  object
# dtypes: float64(8), object(7)
# memory usage: 2.7+ MB

# %%
df_precio_reviews = df[df["price"].isna()==False]
df_precio_reviews = df_precio_reviews[df["last_review"].isna()==False]
df_precio_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14022 entries, 1 to 24975
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14022 non-null  object
#  1   name                            14022 non-null  object
#  2   host_id                         14022 non-null  float64
#  3   host_name                       14022 non-null  object
#  4   neighbourhood_group             14022 non-null  object
#  5   neighbourhood                   14022 non-null  object
#  6   latitude                        14022 non-null  float64
#  7   longitude                       14022 non-null  float64
#  8   room_type                       14022 non-null  object
#  9   price                           14022 non-null  float64
#  10  minimum_nights                  14022 non-null  float64
#  11  number_of_reviews               14022 non-null  float64
#  12  last_review                     14022 non-null  object
#  13  reviews_per_month               14022 non-null  float64
#  14  calculated_host_listings_count  14022 non-null  float64
#  15  availability_365                14022 non-null  float64
#  16  number_of_reviews_ltm           14022 non-null  float64
#  17  license;                        14022 non-null  object
# dtypes: float64(10), object(8)
# memory usage: 2.0+ MB
# C:\Users\javie\AppData\Local\Temp\ipykernel_20332\2133760671.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_precio_reviews = df_precio_reviews[df["last_review"].isna()==False]
